# %%
import sympy as sym
from sympy.utilities.lambdify import lambdify
from functools import partial
from itertools import product
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D

# %%
sym.init_printing(use_unicode=True)
mpl.pyplot.style.use('seaborn-talk')
# %matplotlib inline

# %%
x, t, z, = sym.symbols('x t z')
phi,theta1, theta2 = sym.symbols('phi theta_1, theta_2', real=True)
c, rho, delta = sym.symbols('c, rho, delta', positive=True, real=True)

# %% [markdown]
# ## Define the relevant variables

# %%
a = (rho * x) / (1 + c * x)
a
# Out:
#   ρ⋅x
# ───────
# c⋅x + 1

# %%
b = delta * sym.log(1 + c * x)
b
# Out:
# δ⋅log(c⋅x + 1)

# %%
ratio1 = phi / sym.sqrt(c * ( 1 + phi))

# %%
alpha = x * (ratio1 + (1-phi**2)*(theta2 - sym.Rational(1,2))) - sym.Rational(1/2) * x**2 * (1-phi**2)
alpha
# Out:
#    2 ⎛   2    ⎞
#   x ⋅⎝- φ  + 1⎠     ⎛⎛   2    ⎞                   φ      ⎞
# - ───────────── + x⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟
#         2           ⎜                             _______⎟
#                     ⎝                        √c⋅╲╱ φ + 1 ⎠

# %%
beta = x * (a.replace(x, - ratio1 + theta1 + alpha.replace(x, theta2)) 
            - a.replace(x, theta1 + alpha.replace(x, theta2)))
beta
# Out:
#   ⎛    ⎛       2 ⎛   2    ⎞
#   ⎜    ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ      ⎞
#   ⎜  ρ⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟ - ────
#   ⎜    ⎜           2             ⎜                             _______⎟
#   ⎜    ⎝                         ⎝                        √c⋅╲╱ φ + 1 ⎠   √c⋅╲
# x⋅⎜───────────────────────────────────────────────────────────────────────────
#   ⎜  ⎛       2 ⎛   2    ⎞
#   ⎜  ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ      ⎞        φ
#   ⎜c⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟ - ──────
#   ⎜  ⎜           2             ⎜                             _______⎟        _
#   ⎝  ⎝                         ⎝                        √c⋅╲╱ φ + 1 ⎠   √c⋅╲╱
#
#         ⎞         ⎛       2 ⎛   2    ⎞
#  φ      ⎟         ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ
# ────────⎟       ρ⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ─────────
#  _______⎟         ⎜           2             ⎜                             ____
# ╱ φ + 1 ⎠         ⎝                         ⎝                        √c⋅╲╱ φ +
# ─────────── - ────────────────────────────────────────────────────────────────
#       ⎞         ⎛       2 ⎛   2    ⎞
#       ⎟         ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ
# ──────⎟ + 1   c⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ───────────
# ______⎟         ⎜           2             ⎜                             ______
# φ + 1 ⎠         ⎝                         ⎝                        √c⋅╲╱ φ + 1
#
#     ⎞  ⎞
#    ⎞⎟  ⎟
# ───⎟⎟  ⎟
# ___⎟⎟  ⎟
#  1 ⎠⎠  ⎟
# ───────⎟
#   ⎞    ⎟
#  ⎞⎟    ⎟
# ─⎟⎟ + 1⎟
# _⎟⎟    ⎟
#  ⎠⎠    ⎠

# %%
gamma = x * (b.replace(x, -ratio1 + theta1 + alpha.replace(x, theta2)) 
         - b.replace(x, theta1 + alpha.replace(x, theta2)))
gamma
# Out:
#   ⎛       ⎛  ⎛       2 ⎛   2    ⎞                                            ⎞
#   ⎜       ⎜  ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ      ⎞⎟
# x⋅⎜- δ⋅log⎜c⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟⎟
#   ⎜       ⎜  ⎜           2             ⎜                             _______⎟⎟
#   ⎝       ⎝  ⎝                         ⎝                        √c⋅╲╱ φ + 1 ⎠⎠
#
#     ⎞        ⎛  ⎛       2 ⎛   2    ⎞
#     ⎟        ⎜  ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ
#  + 1⎟ + δ⋅log⎜c⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ───────────
#     ⎟        ⎜  ⎜           2             ⎜                             ______
#     ⎠        ⎝  ⎝                         ⎝                        √c⋅╲╱ φ + 1
#
#                  ⎞    ⎞⎞
#  ⎞        φ      ⎟    ⎟⎟
# ─⎟ - ────────────⎟ + 1⎟⎟
# _⎟        _______⎟    ⎟⎟
#  ⎠   √c⋅╲╱ φ + 1 ⎠    ⎠⎠

# %%
gamma.replace(c,1).replace(delta, 1).replace(phi, -.2)
# Out:
#   ⎛     ⎛            2                                       ⎞      ⎛
# x⋅⎝- log⎝θ₁ - 0.48⋅θ₂  + θ₂⋅(0.96⋅θ₂ - 0.703606797749979) + 1⎠ + log⎝θ₁ - 0.48
#
#    2                                                      ⎞⎞
# ⋅θ₂  + θ₂⋅(0.96⋅θ₂ - 0.703606797749979) + 1.22360679774998⎠⎠

# %%
beta.replace(c,1).replace(delta, 1).replace(rho, .9).replace(phi, -.2)
# Out:
#   ⎛      ⎛            2                                   ⎞       ⎛
#   ⎜  0.9⋅⎝θ₁ - 0.48⋅θ₂  + θ₂⋅(0.96⋅θ₂ - 0.703606797749979)⎠   0.9⋅⎝θ₁ - 0.48⋅θ
# x⋅⎜- ────────────────────────────────────────────────────── + ────────────────
#   ⎜               2                                                          2
#   ⎝   θ₁ - 0.48⋅θ₂  + θ₂⋅(0.96⋅θ₂ - 0.703606797749979) + 1       θ₁ - 0.48⋅θ₂
#
#  2                                                       ⎞⎞
# ₂  + θ₂⋅(0.96⋅θ₂ - 0.703606797749979) + 0.223606797749979⎠⎟
# ──────────────────────────────────────────────────────────⎟
#                                                           ⎟
#  + θ₂⋅(0.96⋅θ₂ - 0.703606797749979) + 1.22360679774998    ⎠

# %% [markdown]
# ## I now take the derivatives

# %% [markdown]
# ### a(x)

# %%
a.diff(rho,1)
# Out:
#    x
# ───────
# c⋅x + 1

# %%
a.diff(c, 1)
# Out:
#       2
#   -ρ⋅x
# ──────────
#          2
# (c⋅x + 1)

# %% [markdown]
# ### b(x)

# %%
b.diff(delta, 1)
# Out:
# log(c⋅x + 1)

# %%
b.diff(c, 1)
# Out:
#   δ⋅x
# ───────
# c⋅x + 1

# %% [markdown]
# ### $\alpha(x)$

# %%
theta2val = sym.solveset(alpha.diff(phi, 1), theta2).args[0]

# %%
theta2val
# Out:
#                     3/2
# 1   2⋅√c⋅φ⋅x⋅(φ + 1)    + φ + 2
# ─ + ───────────────────────────
# 2                      3/2
#          4⋅√c⋅φ⋅(φ + 1)

# %%
alpha.diff(theta2, 1)
# Out:
#   ⎛   2    ⎞
# x⋅⎝- φ  + 1⎠

# %%
alpha.diff(c, 1)
# Out:
#      -φ⋅x
# ────────────────
#    3/2   _______
# 2⋅c   ⋅╲╱ φ + 1

# %% [markdown]
# ### $\beta(x)$

# %%
beta.diff(phi, 1)
# Out:
#   ⎛      ⎛       2 ⎛   2    ⎞
#   ⎜      ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ      ⎞
#   ⎜  c⋅ρ⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟ - ──
#   ⎜      ⎜           2             ⎜                             _______⎟
#   ⎜      ⎝                         ⎝                        √c⋅╲╱ φ + 1 ⎠   √c
# x⋅⎜- ─────────────────────────────────────────────────────────────────────────
#   ⎜
#   ⎜                                                ⎛  ⎛       2 ⎛   2    ⎞
#   ⎜                                                ⎜  ⎜     θ₂ ⋅⎝- φ  + 1⎠
#   ⎜                                                ⎜c⋅⎜θ₁ - ────────────── + θ
#   ⎜                                                ⎜  ⎜           2
#   ⎝                                                ⎝  ⎝
#
#           ⎞
#    φ      ⎟ ⎛    2      ⎛                         φ               1      ⎞
# ──────────⎟⋅⎜φ⋅θ₂  + θ₂⋅⎜-2⋅φ⋅(θ₂ - 1/2) - ─────────────── + ────────────⎟ + ─
#    _______⎟ ⎜           ⎜                              3/2        _______⎟
# ⋅╲╱ φ + 1 ⎠ ⎝           ⎝                  2⋅√c⋅(φ + 1)      √c⋅╲╱ φ + 1 ⎠   2
# ──────────────────────────────────────────────────────────────────────────────
#                                                              2
#                                                        ⎞    ⎞
#   ⎛⎛   2    ⎞                   φ      ⎞        φ      ⎟    ⎟
# ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟ - ────────────⎟ + 1⎟
#   ⎜                             _______⎟        _______⎟    ⎟
#   ⎝                        √c⋅╲╱ φ + 1 ⎠   √c⋅╲╱ φ + 1 ⎠    ⎠
#
#
#       φ               1      ⎞       ⎛    2      ⎛                         φ
# ────────────── - ────────────⎟   c⋅ρ⋅⎜φ⋅θ₂  + θ₂⋅⎜-2⋅φ⋅(θ₂ - 1/2) - ──────────
#            3/2        _______⎟       ⎜           ⎜
# ⋅√c⋅(φ + 1)      √c⋅╲╱ φ + 1 ⎠       ⎝           ⎝                  2⋅√c⋅(φ +
# ────────────────────────────── + ─────────────────────────────────────────────
#
#                                                                ⎛  ⎛       2 ⎛
#                                                                ⎜  ⎜     θ₂ ⋅⎝-
#                                                                ⎜c⋅⎜θ₁ - ──────
#                                                                ⎜  ⎜
#                                                                ⎝  ⎝
#
#                        ⎛       2 ⎛   2    ⎞
#              1      ⎞⎞ ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞
# ───── + ────────────⎟⎟⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────
#   3/2        _______⎟⎟ ⎜           2             ⎜
# 1)      √c⋅╲╱ φ + 1 ⎠⎠ ⎝                         ⎝                        √c⋅╲
# ──────────────────────────────────────────────────────────────────────────────
#                                                           2
#   2    ⎞                                            ⎞    ⎞
#  φ  + 1⎠      ⎛⎛   2    ⎞                   φ      ⎞⎟    ⎟
# ──────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟⎟ + 1⎟
# 2             ⎜                             _______⎟⎟    ⎟
#               ⎝                        √c⋅╲╱ φ + 1 ⎠⎠    ⎠
#
#          ⎞
#  φ      ⎞⎟     ⎛    2      ⎛                         φ               1      ⎞
# ────────⎟⎟   ρ⋅⎜φ⋅θ₂  + θ₂⋅⎜-2⋅φ⋅(θ₂ - 1/2) - ─────────────── + ────────────⎟
#  _______⎟⎟     ⎜           ⎜                              3/2        _______⎟
# ╱ φ + 1 ⎠⎠     ⎝           ⎝                  2⋅√c⋅(φ + 1)      √c⋅╲╱ φ + 1 ⎠
# ────────── + ─────────────────────────────────────────────────────────────────
#                      ⎛       2 ⎛   2    ⎞
#                      ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ
#                    c⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ──────
#                      ⎜           2             ⎜                             _
#                      ⎝                         ⎝                        √c⋅╲╱
#
#
#
#          φ               1      ⎞        ⎛    2      ⎛
# + ─────────────── - ────────────⎟      ρ⋅⎜φ⋅θ₂  + θ₂⋅⎜-2⋅φ⋅(θ₂ - 1/2) - ──────
#               3/2        _______⎟        ⎜           ⎜
#   2⋅√c⋅(φ + 1)      √c⋅╲╱ φ + 1 ⎠        ⎝           ⎝                  2⋅√c⋅(
# ───────────────────────────────── - ──────────────────────────────────────────
#                       ⎞               ⎛       2 ⎛   2    ⎞
#       ⎞        φ      ⎟               ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞
# ──────⎟ - ────────────⎟ + 1         c⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ
# ______⎟        _______⎟               ⎜           2             ⎜
# φ + 1 ⎠   √c⋅╲╱ φ + 1 ⎠               ⎝                         ⎝
#
#
#                              ⎞
#  φ               1      ⎞⎞   ⎟
# ───────── + ────────────⎟⎟   ⎟
#       3/2        _______⎟⎟   ⎟
# φ + 1)      √c⋅╲╱ φ + 1 ⎠⎠   ⎟
# ─────────────────────────────⎟
#                         ⎞    ⎟
#                 φ      ⎞⎟    ⎟
# ₂ - 1/2) + ────────────⎟⎟ + 1⎟
#                 _______⎟⎟    ⎟
#            √c⋅╲╱ φ + 1 ⎠⎠    ⎟
#                              ⎠

# %%
beta.diff(phi,1)
# Out:
#   ⎛      ⎛       2 ⎛   2    ⎞
#   ⎜      ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ      ⎞
#   ⎜  c⋅ρ⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟ - ──
#   ⎜      ⎜           2             ⎜                             _______⎟
#   ⎜      ⎝                         ⎝                        √c⋅╲╱ φ + 1 ⎠   √c
# x⋅⎜- ─────────────────────────────────────────────────────────────────────────
#   ⎜
#   ⎜                                                ⎛  ⎛       2 ⎛   2    ⎞
#   ⎜                                                ⎜  ⎜     θ₂ ⋅⎝- φ  + 1⎠
#   ⎜                                                ⎜c⋅⎜θ₁ - ────────────── + θ
#   ⎜                                                ⎜  ⎜           2
#   ⎝                                                ⎝  ⎝
#
#           ⎞
#    φ      ⎟ ⎛    2      ⎛                         φ               1      ⎞
# ──────────⎟⋅⎜φ⋅θ₂  + θ₂⋅⎜-2⋅φ⋅(θ₂ - 1/2) - ─────────────── + ────────────⎟ + ─
#    _______⎟ ⎜           ⎜                              3/2        _______⎟
# ⋅╲╱ φ + 1 ⎠ ⎝           ⎝                  2⋅√c⋅(φ + 1)      √c⋅╲╱ φ + 1 ⎠   2
# ──────────────────────────────────────────────────────────────────────────────
#                                                              2
#                                                        ⎞    ⎞
#   ⎛⎛   2    ⎞                   φ      ⎞        φ      ⎟    ⎟
# ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟ - ────────────⎟ + 1⎟
#   ⎜                             _______⎟        _______⎟    ⎟
#   ⎝                        √c⋅╲╱ φ + 1 ⎠   √c⋅╲╱ φ + 1 ⎠    ⎠
#
#
#       φ               1      ⎞       ⎛    2      ⎛                         φ
# ────────────── - ────────────⎟   c⋅ρ⋅⎜φ⋅θ₂  + θ₂⋅⎜-2⋅φ⋅(θ₂ - 1/2) - ──────────
#            3/2        _______⎟       ⎜           ⎜
# ⋅√c⋅(φ + 1)      √c⋅╲╱ φ + 1 ⎠       ⎝           ⎝                  2⋅√c⋅(φ +
# ────────────────────────────── + ─────────────────────────────────────────────
#
#                                                                ⎛  ⎛       2 ⎛
#                                                                ⎜  ⎜     θ₂ ⋅⎝-
#                                                                ⎜c⋅⎜θ₁ - ──────
#                                                                ⎜  ⎜
#                                                                ⎝  ⎝
#
#                        ⎛       2 ⎛   2    ⎞
#              1      ⎞⎞ ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞
# ───── + ────────────⎟⎟⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────
#   3/2        _______⎟⎟ ⎜           2             ⎜
# 1)      √c⋅╲╱ φ + 1 ⎠⎠ ⎝                         ⎝                        √c⋅╲
# ──────────────────────────────────────────────────────────────────────────────
#                                                           2
#   2    ⎞                                            ⎞    ⎞
#  φ  + 1⎠      ⎛⎛   2    ⎞                   φ      ⎞⎟    ⎟
# ──────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟⎟ + 1⎟
# 2             ⎜                             _______⎟⎟    ⎟
#               ⎝                        √c⋅╲╱ φ + 1 ⎠⎠    ⎠
#
#          ⎞
#  φ      ⎞⎟     ⎛    2      ⎛                         φ               1      ⎞
# ────────⎟⎟   ρ⋅⎜φ⋅θ₂  + θ₂⋅⎜-2⋅φ⋅(θ₂ - 1/2) - ─────────────── + ────────────⎟
#  _______⎟⎟     ⎜           ⎜                              3/2        _______⎟
# ╱ φ + 1 ⎠⎠     ⎝           ⎝                  2⋅√c⋅(φ + 1)      √c⋅╲╱ φ + 1 ⎠
# ────────── + ─────────────────────────────────────────────────────────────────
#                      ⎛       2 ⎛   2    ⎞
#                      ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ
#                    c⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ──────
#                      ⎜           2             ⎜                             _
#                      ⎝                         ⎝                        √c⋅╲╱
#
#
#
#          φ               1      ⎞        ⎛    2      ⎛
# + ─────────────── - ────────────⎟      ρ⋅⎜φ⋅θ₂  + θ₂⋅⎜-2⋅φ⋅(θ₂ - 1/2) - ──────
#               3/2        _______⎟        ⎜           ⎜
#   2⋅√c⋅(φ + 1)      √c⋅╲╱ φ + 1 ⎠        ⎝           ⎝                  2⋅√c⋅(
# ───────────────────────────────── - ──────────────────────────────────────────
#                       ⎞               ⎛       2 ⎛   2    ⎞
#       ⎞        φ      ⎟               ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞
# ──────⎟ - ────────────⎟ + 1         c⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ
# ______⎟        _______⎟               ⎜           2             ⎜
# φ + 1 ⎠   √c⋅╲╱ φ + 1 ⎠               ⎝                         ⎝
#
#
#                              ⎞
#  φ               1      ⎞⎞   ⎟
# ───────── + ────────────⎟⎟   ⎟
#       3/2        _______⎟⎟   ⎟
# φ + 1)      √c⋅╲╱ φ + 1 ⎠⎠   ⎟
# ─────────────────────────────⎟
#                         ⎞    ⎟
#                 φ      ⎞⎟    ⎟
# ₂ - 1/2) + ────────────⎟⎟ + 1⎟
#                 _______⎟⎟    ⎟
#            √c⋅╲╱ φ + 1 ⎠⎠    ⎟
#                              ⎠

# %%
beta.diff(c,1)
# Out:
#   ⎛
#   ⎜                        ⎛        φ⋅θ₂                φ        ⎞
#   ⎜                      ρ⋅⎜- ──────────────── + ────────────────⎟
#   ⎜                        ⎜     3/2   _______      3/2   _______⎟
#   ⎜                        ⎝  2⋅c   ⋅╲╱ φ + 1    2⋅c   ⋅╲╱ φ + 1 ⎠
# x⋅⎜───────────────────────────────────────────────────────────────────────────
#   ⎜  ⎛       2 ⎛   2    ⎞
#   ⎜  ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ      ⎞        φ
#   ⎜c⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟ - ──────
#   ⎜  ⎜           2             ⎜                             _______⎟        _
#   ⎜  ⎝                         ⎝                        √c⋅╲╱ φ + 1 ⎠   √c⋅╲╱
#   ⎝
#
#                 ⎛       2 ⎛   2    ⎞
#                 ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ
#               ρ⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ───────────
#                 ⎜           2             ⎜                             ______
#                 ⎝                         ⎝                        √c⋅╲╱ φ + 1
# ─────────── + ────────────────────────────────────────────────────────────────
#       ⎞
#       ⎟                                                                   ⎛  ⎛
# ──────⎟ + 1                                                               ⎜  ⎜
# ______⎟                                                                   ⎜c⋅⎜
# φ + 1 ⎠                                                                   ⎜  ⎜
#                                                                           ⎝  ⎝
#
#                  ⎞ ⎛                                                     2 ⎛
#  ⎞        φ      ⎟ ⎜    ⎛        φ⋅θ₂                φ        ⎞        θ₂ ⋅⎝-
# ─⎟ - ────────────⎟⋅⎜- c⋅⎜- ──────────────── + ────────────────⎟ - θ₁ + ───────
# _⎟        _______⎟ ⎜    ⎜     3/2   _______      3/2   _______⎟              2
#  ⎠   √c⋅╲╱ φ + 1 ⎠ ⎝    ⎝  2⋅c   ⋅╲╱ φ + 1    2⋅c   ⋅╲╱ φ + 1 ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#        2 ⎛   2    ⎞
#      θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ      ⎞        φ
# θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟ - ────────────
#            2             ⎜                             _______⎟        _______
#                          ⎝                        √c⋅╲╱ φ + 1 ⎠   √c⋅╲╱ φ + 1
#
#  2    ⎞                                                           ⎞     ⎛
# φ  + 1⎠      ⎛⎛   2    ⎞                   φ      ⎞        φ      ⎟     ⎜
# ─────── - θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟ + ────────────⎟   ρ⋅⎜θ₁ -
#              ⎜                             _______⎟        _______⎟     ⎜
#              ⎝                        √c⋅╲╱ φ + 1 ⎠   √c⋅╲╱ φ + 1 ⎠     ⎝
# ─────────────────────────────────────────────────────────────────── - ────────
#       2
# ⎞    ⎞
# ⎟    ⎟
# ⎟ + 1⎟
# ⎟    ⎟
# ⎠    ⎠
#
#   2 ⎛   2    ⎞                                            ⎞ ⎛        2 ⎛   2
# θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ      ⎞⎟ ⎜      θ₂ ⋅⎝- φ  +
# ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟⎟⋅⎜-θ₁ + ───────────
#       2             ⎜                             _______⎟⎟ ⎜            2
#                     ⎝                        √c⋅╲╱ φ + 1 ⎠⎠ ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#                                ⎛  ⎛       2 ⎛   2    ⎞
#                                ⎜  ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞
#                                ⎜c⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ -
#                                ⎜  ⎜           2             ⎜
#                                ⎝  ⎝                         ⎝
#
#   ⎞                                                             ⎞
#  1⎠      ⎛⎛   2    ⎞                   φ      ⎞        φ⋅θ₂     ⎟
# ─── - θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟ + ──────────────⎟
#          ⎜                             _______⎟          _______⎟
#          ⎝                        √c⋅╲╱ φ + 1 ⎠   2⋅√c⋅╲╱ φ + 1 ⎠
# ───────────────────────────────────────────────────────────────── + ──────────
#                           2
#                     ⎞    ⎞                                             3/2   _
#             φ      ⎞⎟    ⎟                                          2⋅c   ⋅╲╱
# 1/2) + ────────────⎟⎟ + 1⎟
#             _______⎟⎟    ⎟
#        √c⋅╲╱ φ + 1 ⎠⎠    ⎠
#
#
#
#
#
#                                 φ⋅ρ⋅θ₂
# ──────────────────────────────────────────────────────────────────────────────
#        ⎛  ⎛       2 ⎛   2    ⎞                                            ⎞
# ______ ⎜  ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ      ⎞⎟
# φ + 1 ⋅⎜c⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟⎟ +
#        ⎜  ⎜           2             ⎜                             _______⎟⎟
#        ⎝  ⎝                         ⎝                        √c⋅╲╱ φ + 1 ⎠⎠
#
#
#   ⎞
#   ⎟
#   ⎟
#   ⎟
#   ⎟
# ──⎟
#  ⎞⎟
#  ⎟⎟
# 1⎟⎟
#  ⎟⎟
#  ⎠⎟
#   ⎠

# %%
sym.diff(beta, theta1)
# Out:
#   ⎛         ⎛       2 ⎛   2    ⎞
#   ⎜         ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ      ⎞
#   ⎜     c⋅ρ⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟ -
#   ⎜         ⎜           2             ⎜                             _______⎟
#   ⎜         ⎝                         ⎝                        √c⋅╲╱ φ + 1 ⎠
# x⋅⎜- ─────────────────────────────────────────────────────────────────────────
#   ⎜
#   ⎜  ⎛  ⎛       2 ⎛   2    ⎞
#   ⎜  ⎜  ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ      ⎞
#   ⎜  ⎜c⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟ - ───
#   ⎜  ⎜  ⎜           2             ⎜                             _______⎟
#   ⎝  ⎝  ⎝                         ⎝                        √c⋅╲╱ φ + 1 ⎠   √c⋅
#
#              ⎞           ⎛       2 ⎛   2    ⎞
#       φ      ⎟           ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞
#  ────────────⎟       c⋅ρ⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ──
#       _______⎟           ⎜           2             ⎜
#  √c⋅╲╱ φ + 1 ⎠           ⎝                         ⎝                        √c
# ──────────────── + ───────────────────────────────────────────────────────────
#                2
#          ⎞    ⎞    ⎛  ⎛       2 ⎛   2    ⎞
#   φ      ⎟    ⎟    ⎜  ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞
# ─────────⎟ + 1⎟    ⎜c⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ─────
#   _______⎟    ⎟    ⎜  ⎜           2             ⎜
# ╲╱ φ + 1 ⎠    ⎠    ⎝  ⎝                         ⎝                        √c⋅╲╱
#
#            ⎞
#    φ      ⎞⎟
# ──────────⎟⎟
#    _______⎟⎟
# ⋅╲╱ φ + 1 ⎠⎠                                                ρ
# ─────────────── + ────────────────────────────────────────────────────────────
#               2     ⎛       2 ⎛   2    ⎞
#         ⎞    ⎞      ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ
# φ      ⎞⎟    ⎟    c⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ───────
# ───────⎟⎟ + 1⎟      ⎜           2             ⎜                             __
# _______⎟⎟    ⎟      ⎝                         ⎝                        √c⋅╲╱ φ
#  φ + 1 ⎠⎠    ⎠
#
#
#
#
#
#                                                                 ρ
# ────────────────────────── - ─────────────────────────────────────────────────
#                      ⎞         ⎛       2 ⎛   2    ⎞
#      ⎞        φ      ⎟         ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞
# ─────⎟ - ────────────⎟ + 1   c⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2
# _____⎟        _______⎟         ⎜           2             ⎜
#  + 1 ⎠   √c⋅╲╱ φ + 1 ⎠         ⎝                         ⎝
#
#
#                       ⎞
#                       ⎟
#                       ⎟
#                       ⎟
#                       ⎟
# ──────────────────────⎟
#                  ⎞    ⎟
#          φ      ⎞⎟    ⎟
# ) + ────────────⎟⎟ + 1⎟
#          _______⎟⎟    ⎟
#     √c⋅╲╱ φ + 1 ⎠⎠    ⎟
#                       ⎠

# %%
sym.diff(beta, theta2)
# Out:
#   ⎛                                             ⎛       2 ⎛   2    ⎞
#   ⎜      ⎛⎛   2    ⎞                   φ      ⎞ ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛
#   ⎜  c⋅ρ⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝-
#   ⎜      ⎜                             _______⎟ ⎜           2             ⎜
#   ⎜      ⎝                        √c⋅╲╱ φ + 1 ⎠ ⎝                         ⎝
# x⋅⎜- ─────────────────────────────────────────────────────────────────────────
#   ⎜
#   ⎜                   ⎛  ⎛       2 ⎛   2    ⎞
#   ⎜                   ⎜  ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞
#   ⎜                   ⎜c⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ──
#   ⎜                   ⎜  ⎜           2             ⎜
#   ⎝                   ⎝  ⎝                         ⎝                        √c
#
#                                                  ⎞
#  2    ⎞                   φ      ⎞        φ      ⎟       ⎛⎛   2    ⎞
# φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟ - ────────────⎟   c⋅ρ⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2
#                           _______⎟        _______⎟       ⎜
#                      √c⋅╲╱ φ + 1 ⎠   √c⋅╲╱ φ + 1 ⎠       ⎝
# ────────────────────────────────────────────────── + ─────────────────────────
#                                 2
#                           ⎞    ⎞                                      ⎛  ⎛
#    φ      ⎞        φ      ⎟    ⎟                                      ⎜  ⎜
# ──────────⎟ - ────────────⎟ + 1⎟                                      ⎜c⋅⎜θ₁ -
#    _______⎟        _______⎟    ⎟                                      ⎜  ⎜
# ⋅╲╱ φ + 1 ⎠   √c⋅╲╱ φ + 1 ⎠    ⎠                                      ⎝  ⎝
#
#                   ⎛       2 ⎛   2    ⎞
#          φ      ⎞ ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ
# ) + ────────────⎟⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ─────────
#          _______⎟ ⎜           2             ⎜                             ____
#     √c⋅╲╱ φ + 1 ⎠ ⎝                         ⎝                        √c⋅╲╱ φ +
# ──────────────────────────────────────────────────────────────────────────────
#                                                                  2
#    2 ⎛   2    ⎞                                            ⎞    ⎞
#  θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ      ⎞⎟    ⎟
#  ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟⎟ + 1⎟
#        2             ⎜                             _______⎟⎟    ⎟
#                      ⎝                        √c⋅╲╱ φ + 1 ⎠⎠    ⎠
#
#     ⎞
#    ⎞⎟                            ⎛⎛   2    ⎞                   φ      ⎞
# ───⎟⎟                          ρ⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟
# ___⎟⎟                            ⎜                             _______⎟
#  1 ⎠⎠                            ⎝                        √c⋅╲╱ φ + 1 ⎠
# ───── + ──────────────────────────────────────────────────────────────────────
#           ⎛       2 ⎛   2    ⎞
#           ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ      ⎞
#         c⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟ - ─
#           ⎜           2             ⎜                             _______⎟
#           ⎝                         ⎝                        √c⋅╲╱ φ + 1 ⎠   √
#
#
#
#                                      ⎛⎛   2    ⎞                   φ      ⎞
#                                    ρ⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟
#                                      ⎜                             _______⎟
#                                      ⎝                        √c⋅╲╱ φ + 1 ⎠
# ──────────────── - ───────────────────────────────────────────────────────────
#            ⎞         ⎛       2 ⎛   2    ⎞
#     φ      ⎟         ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ
# ───────────⎟ + 1   c⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ──────
#     _______⎟         ⎜           2             ⎜                             _
# c⋅╲╱ φ + 1 ⎠         ⎝                         ⎝                        √c⋅╲╱
#
#
#             ⎞
#             ⎟
#             ⎟
#             ⎟
#             ⎟
# ────────────⎟
#        ⎞    ⎟
#       ⎞⎟    ⎟
# ──────⎟⎟ + 1⎟
# ______⎟⎟    ⎟
# φ + 1 ⎠⎠    ⎟
#             ⎠

# %% [markdown]
# ### $\gamma(x)$

# %%
sym.diff(gamma, phi)
# Out:
#   ⎛    ⎛    2      ⎛                         φ               1      ⎞
#   ⎜c⋅δ⋅⎜φ⋅θ₂  + θ₂⋅⎜-2⋅φ⋅(θ₂ - 1/2) - ─────────────── + ────────────⎟ + ──────
#   ⎜    ⎜           ⎜                              3/2        _______⎟
#   ⎜    ⎝           ⎝                  2⋅√c⋅(φ + 1)      √c⋅╲╱ φ + 1 ⎠   2⋅√c⋅(
# x⋅⎜───────────────────────────────────────────────────────────────────────────
#   ⎜         ⎛       2 ⎛   2    ⎞
#   ⎜         ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ      ⎞
#   ⎜       c⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟ -
#   ⎜         ⎜           2             ⎜                             _______⎟
#   ⎝         ⎝                         ⎝                        √c⋅╲╱ φ + 1 ⎠
#
#  φ               1      ⎞         ⎛    2      ⎛                         φ
# ───────── - ────────────⎟     c⋅δ⋅⎜φ⋅θ₂  + θ₂⋅⎜-2⋅φ⋅(θ₂ - 1/2) - ─────────────
#       3/2        _______⎟         ⎜           ⎜                              3
# φ + 1)      √c⋅╲╱ φ + 1 ⎠         ⎝           ⎝                  2⋅√c⋅(φ + 1)
# ───────────────────────── - ──────────────────────────────────────────────────
#              ⎞                ⎛       2 ⎛   2    ⎞
#       φ      ⎟                ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞
#  ────────────⎟ + 1          c⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2)
#       _______⎟                ⎜           2             ⎜
#  √c⋅╲╱ φ + 1 ⎠                ⎝                         ⎝
#
#           1      ⎞⎞  ⎞
# ── + ────────────⎟⎟  ⎟
# /2        _______⎟⎟  ⎟
#      √c⋅╲╱ φ + 1 ⎠⎠  ⎟
# ─────────────────────⎟
#                 ⎞    ⎟
#         φ      ⎞⎟    ⎟
#  + ────────────⎟⎟ + 1⎟
#         _______⎟⎟    ⎟
#    √c⋅╲╱ φ + 1 ⎠⎠    ⎠

# %%
sym.sympify(sym.diff(gamma, theta1).replace(theta2,theta2val).replace(x,1))
# Out:
#
# ──────────────────────────────────────────────────────────────────────────────
#   ⎛                                    2
#   ⎜     ⎛                  3/2        ⎞
#   ⎜     ⎜1   2⋅√c⋅φ⋅(φ + 1)    + φ + 2⎟  ⎛   2    ⎞
#   ⎜     ⎜─ + ─────────────────────────⎟ ⋅⎝- φ  + 1⎠
#   ⎜     ⎜2                     3/2    ⎟               ⎛                  3/2
#   ⎜     ⎝        4⋅√c⋅φ⋅(φ + 1)       ⎠               ⎜1   2⋅√c⋅φ⋅(φ + 1)    +
# c⋅⎜θ₁ - ─────────────────────────────────────────── + ⎜─ + ───────────────────
#   ⎜                          2                        ⎜2                     3
#   ⎝                                                   ⎝        4⋅√c⋅φ⋅(φ + 1)
#
#  c⋅δ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#       ⎞ ⎛               ⎛   2    ⎞ ⎛              3/2        ⎞⎞
#  φ + 2⎟ ⎜     φ         ⎝- φ  + 1⎠⋅⎝2⋅√c⋅φ⋅(φ + 1)    + φ + 2⎠⎟        φ
# ──────⎟⋅⎜──────────── + ──────────────────────────────────────⎟ - ────────────
# /2    ⎟ ⎜     _______                           3/2           ⎟        _______
#       ⎠ ⎝√c⋅╲╱ φ + 1              4⋅√c⋅φ⋅(φ + 1)              ⎠   √c⋅╲╱ φ + 1
#
#
# ───── - ──────────────────────────────────────────────────────────────────────
# ⎞         ⎛                                    2
# ⎟         ⎜     ⎛                  3/2        ⎞
# ⎟         ⎜     ⎜1   2⋅√c⋅φ⋅(φ + 1)    + φ + 2⎟  ⎛   2    ⎞
# ⎟         ⎜     ⎜─ + ─────────────────────────⎟ ⋅⎝- φ  + 1⎠
# ⎟         ⎜     ⎜2                     3/2    ⎟               ⎛
# ⎟         ⎜     ⎝        4⋅√c⋅φ⋅(φ + 1)       ⎠               ⎜1   2⋅√c⋅φ⋅(φ +
# ⎟ + 1   c⋅⎜θ₁ - ─────────────────────────────────────────── + ⎜─ + ───────────
# ⎟         ⎜                          2                        ⎜2
# ⎠         ⎝                                                   ⎝        4⋅√c⋅φ⋅
#
#  c⋅δ
# ────────────────────────────────────────────────────────────────────────────
#                                                                        ⎞
#                                                                        ⎟
#                                                                        ⎟
#                                                                        ⎟
#    3/2        ⎞ ⎛               ⎛   2    ⎞ ⎛              3/2        ⎞⎞⎟
#  1)    + φ + 2⎟ ⎜     φ         ⎝- φ  + 1⎠⋅⎝2⋅√c⋅φ⋅(φ + 1)    + φ + 2⎠⎟⎟
# ──────────────⎟⋅⎜──────────── + ──────────────────────────────────────⎟⎟ + 1
#        3/2    ⎟ ⎜     _______                           3/2           ⎟⎟
# (φ + 1)       ⎠ ⎝√c⋅╲╱ φ + 1              4⋅√c⋅φ⋅(φ + 1)              ⎠⎠

# %%
theta2val
# Out:
#                     3/2
# 1   2⋅√c⋅φ⋅x⋅(φ + 1)    + φ + 2
# ─ + ───────────────────────────
# 2                      3/2
#          4⋅√c⋅φ⋅(φ + 1)

# %%
sym.diff(gamma, theta2)
# Out:
#   ⎛                          ⎛⎛   2    ⎞                   φ      ⎞
#   ⎜                      c⋅δ⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟
#   ⎜                          ⎜                             _______⎟
#   ⎜                          ⎝                        √c⋅╲╱ φ + 1 ⎠
# x⋅⎜───────────────────────────────────────────────────────────────────────────
#   ⎜  ⎛       2 ⎛   2    ⎞
#   ⎜  ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ      ⎞        φ
#   ⎜c⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟ - ──────
#   ⎜  ⎜           2             ⎜                             _______⎟        _
#   ⎝  ⎝                         ⎝                        √c⋅╲╱ φ + 1 ⎠   √c⋅╲╱
#
#                                  ⎛⎛   2    ⎞                   φ      ⎞
#                              c⋅δ⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟
#                                  ⎜                             _______⎟
#                                  ⎝                        √c⋅╲╱ φ + 1 ⎠
# ─────────── - ────────────────────────────────────────────────────────────────
#       ⎞         ⎛       2 ⎛   2    ⎞
#       ⎟         ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ
# ──────⎟ + 1   c⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ───────────
# ______⎟         ⎜           2             ⎜                             ______
# φ + 1 ⎠         ⎝                         ⎝                        √c⋅╲╱ φ + 1
#
#        ⎞
#        ⎟
#        ⎟
#        ⎟
# ───────⎟
#   ⎞    ⎟
#  ⎞⎟    ⎟
# ─⎟⎟ + 1⎟
# _⎟⎟    ⎟
#  ⎠⎠    ⎠

# %%
sym.diff(gamma, delta)
# Out:
#   ⎛     ⎛  ⎛       2 ⎛   2    ⎞                                            ⎞
#   ⎜     ⎜  ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ      ⎞⎟
# x⋅⎜- log⎜c⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟⎟ +
#   ⎜     ⎜  ⎜           2             ⎜                             _______⎟⎟
#   ⎝     ⎝  ⎝                         ⎝                        √c⋅╲╱ φ + 1 ⎠⎠
#
#   ⎞      ⎛  ⎛       2 ⎛   2    ⎞
#   ⎟      ⎜  ⎜     θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ      ⎞
#  1⎟ + log⎜c⋅⎜θ₁ - ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟ -
#   ⎟      ⎜  ⎜           2             ⎜                             _______⎟
#   ⎠      ⎝  ⎝                         ⎝                        √c⋅╲╱ φ + 1 ⎠
#
#              ⎞    ⎞⎞
#       φ      ⎟    ⎟⎟
#  ────────────⎟ + 1⎟⎟
#       _______⎟    ⎟⎟
#  √c⋅╲╱ φ + 1 ⎠    ⎠⎠

# %% [markdown]
# ## Lack of identification issue

# %%
sym.diff(gamma.replace(phi, 0), theta1)
# Out:
# 0

# %%
sym.diff(beta.replace(phi, 0), theta1)
# Out:
# 0

# %%
sym.diff(gamma.replace(theta1, 0), theta2)
# Out:
#   ⎛                         ⎛⎛   2    ⎞                   φ      ⎞
#   ⎜                     c⋅δ⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟
#   ⎜                         ⎜                             _______⎟
#   ⎜                         ⎝                        √c⋅╲╱ φ + 1 ⎠
# x⋅⎜───────────────────────────────────────────────────────────────────────────
#   ⎜  ⎛    2 ⎛   2    ⎞
#   ⎜  ⎜  θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ      ⎞        φ
#   ⎜c⋅⎜- ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟ - ─────────
#   ⎜  ⎜        2             ⎜                             _______⎟        ____
#   ⎝  ⎝                      ⎝                        √c⋅╲╱ φ + 1 ⎠   √c⋅╲╱ φ +
#
#                             ⎛⎛   2    ⎞                   φ      ⎞
#                         c⋅δ⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟
#                             ⎜                             _______⎟
#                             ⎝                        √c⋅╲╱ φ + 1 ⎠
# ──────── - ───────────────────────────────────────────────────────────────────
#    ⎞         ⎛    2 ⎛   2    ⎞                                            ⎞
#    ⎟         ⎜  θ₂ ⋅⎝- φ  + 1⎠      ⎛⎛   2    ⎞                   φ      ⎞⎟
# ───⎟ + 1   c⋅⎜- ────────────── + θ₂⋅⎜⎝- φ  + 1⎠⋅(θ₂ - 1/2) + ────────────⎟⎟ +
# ___⎟         ⎜        2             ⎜                             _______⎟⎟
#  1 ⎠         ⎝                      ⎝                        √c⋅╲╱ φ + 1 ⎠⎠
#
#  ⎞
#  ⎟
#  ⎟
#  ⎟
# ─⎟
#  ⎟
#  ⎟
# 1⎟
#  ⎟
#  ⎠

# %% [markdown]
# ### Parameter Estimates from Renault (Gmm Step)

# %% [markdown]
# rho : 0.95
# delta : 1.25
# phi : -0.30
# theta2 : 0.53

# %%
sym.diff(gamma, theta1).replace(phi, 0)
# Out:
# 0

# %%
gamma_func = partial(lambdify((c, delta, rho, theta2, theta1, x, phi), sym.diff(gamma, theta1)),
                     1, 1.25, .95, .53, -7, .5)

# %%
gamma_diff_fig, gamma_diff_ax = mpl.pyplot.subplots()
xvals = np.linspace(-.99, .99, 100)
yvals = [gamma_func(val) for val in xvals]
gamma_diff_ax.set_xlabel('$\phi$')
gamma_diff_ax.plot(xvals, yvals)
gamma_diff_ax.axhline(0, color='grey')
gamma_diff_ax.axvline(0, color='grey')
gamma_diff_ax.set_yticklabels([])
gamma_diff_fig.savefig('../doc/figures/gamma_diff_theta2.tmp.pdf', frameon=False, transparent=True,
                       bbox_inches='tight',pad_inches=0)

# %%
beta_func = partial(lambdify((c, delta, rho, theta2, theta1, x, phi), sym.diff(beta, theta1)),
                     1, 1.25, .95, .53, -7, .5)

# %%
beta_diff_fig, beta_diff_ax = mpl.pyplot.subplots()
beta_xvals = np.linspace(-.99, .99, 100)
beta_yvals = [beta_func(val) for val in xvals]
beta_diff_ax.set_ylabel('$\phi$')
beta_diff_ax.plot(xvals, yvals)
beta_diff_ax.axhline(0, color='grey')
beta_diff_ax.axvline(0, color='grey')
